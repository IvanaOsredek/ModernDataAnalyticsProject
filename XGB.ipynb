# %%
import pandas as pd
import sklearn
from sklearn.model_selection import TimeSeriesSplit
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_validate
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import numpy as np
import shap

# %% [markdown]
# Dataframe from MDA_merge_data.ipynb is loaded, datetime column is dropped in order to run model.

# %%
df = pd.read_csv("C:/Users/saaan/Downloads/repositories/MDA/ModernDataAnalyticsProject/final_df.csv", delimiter=";")
#select only three locations close to Oude Markt
df = df[df['object_id']<255442]
df['255439'] = df['object_id']==255439
df['255440'] = df['object_id']==255440
df['255441'] = df['object_id']==255441
df = df.sort_values(by=['result_timestamp','object_id'])
df
# Out:
#         object_id     result_timestamp       laeq        date      time  hour  \
# 272166     255441  2022-01-01 00:00:00  63.267554  2022-01-01  00:00:00     0
# 272170     255441  2022-01-01 00:10:00  60.254000  2022-01-01  00:10:00     0
# 272174     255441  2022-01-01 00:20:00  55.143907  2022-01-01  00:20:00     0
# 272178     255441  2022-01-01 00:30:00  58.230167  2022-01-01  00:30:00     0
# 272182     255441  2022-01-01 00:40:00  54.220466  2022-01-01  00:40:00     0
# ...           ...                  ...        ...         ...       ...   ...
# 332425     255441  2022-12-31 23:10:00  53.712833  2022-12-31  23:10:00    23
# 332431     255441  2022-12-31 23:20:00  55.333167  2022-12-31  23:20:00    23
# 332437     255441  2022-12-31 23:30:00  56.797333  2022-12-31  23:30:00    23
# 332443     255441  2022-12-31 23:40:00  61.010667  2022-12-31  23:40:00    23
# 332449     255441  2022-12-31 23:50:00  58.354424  2022-12-31  23:50:00    23
#
#          weekday  month  weekend           day_time  ... LC_WINDDIR  \
# 272166  Saturday      1     True  Saturday 00:00:00  ...        NaN
# 272170  Saturday      1     True  Saturday 00:10:00  ...      -48.0
# 272174  Saturday      1     True  Saturday 00:20:00  ...       45.0
# 272178  Saturday      1     True  Saturday 00:30:00  ...      -52.0
# 272182  Saturday      1     True  Saturday 00:40:00  ...       34.0
# ...          ...    ...      ...                ...  ...        ...
# 332425  Saturday     12     True  Saturday 23:10:00  ...       -9.0
# 332431  Saturday     12     True  Saturday 23:20:00  ...        5.0
# 332437  Saturday     12     True  Saturday 23:30:00  ...      -17.0
# 332443  Saturday     12     True  Saturday 23:40:00  ...      -31.0
# 332449  Saturday     12     True  Saturday 23:50:00  ...       13.0
#
#         LC_WINDSPEED  LC_RAD60  LC_TEMP_QCL0  LC_TEMP_QCL1  LC_TEMP_QCL2  \
# 272166           NaN       NaN           NaN           NaN           NaN
# 272170          0.04       0.0         13.28         13.28        13.223
# 272174          0.02       0.0         13.28         13.28        13.223
# 272178          0.04       0.0         13.28         13.28        13.223
# 272182          0.02       0.0         13.28         13.28        13.223
# ...              ...       ...           ...           ...           ...
# 332425          0.40       0.0         16.61         16.61        16.553
# 332431          0.29       0.0         16.61         16.61        16.553
# 332437          0.15       0.0         16.51         16.51        16.453
# 332443          0.29       0.0         16.49         16.49        16.433
# 332449          0.31       0.0         16.39         16.39        16.333
#
#         LC_TEMP_QCL3  255439  255440  255441
# 272166           NaN   False   False    True
# 272170      13.23639   False   False    True
# 272174      13.16699   False   False    True
# 272178      13.19886   False   False    True
# 272182      13.16699   False   False    True
# ...              ...     ...     ...     ...
# 332425      16.52797   False   False    True
# 332431      16.57995   False   False    True
# 332437      16.44846   False   False    True
# 332443      16.46641   False   False    True
# 332449      16.35838   False   False    True
#
# [131561 rows x 29 columns]

# %%
df['key'] = df['object_id'].astype('str') + df['result_timestamp']
df['result_timestamp'] = pd.to_datetime(df['result_timestamp'],format='%Y-%m-%d %H:%M:%S')

# %%
df_noisedelay = df[['object_id','result_timestamp','laeq']]
df_noisedelay['result_timestamp'] = df_noisedelay['result_timestamp']+pd.DateOffset(hours=6)
df_noisedelay['laeq_delayed'] = df_noisedelay['laeq']
df_noisedelay['key'] = df_noisedelay['object_id'].astype('str') + df_noisedelay['result_timestamp'].astype('str')
df_noisedelay = df_noisedelay.drop(['laeq','object_id','result_timestamp'], axis=1)

df_weatherdelay = df[['object_id','result_timestamp','LC_HUMIDITY','LC_DWPTEMP','LC_n','LC_RAD','LC_RAININ',
                   'LC_DAILYRAIN','LC_WINDDIR','LC_WINDSPEED','LC_RAD60','LC_TEMP_QCL0']]
df_weatherdelay['result_timestamp'] = df_weatherdelay['result_timestamp']+pd.DateOffset(hours=6)
df_weatherdelay['key'] = df_weatherdelay['object_id'].astype('str') + df_weatherdelay['result_timestamp'].astype('str')
df_weatherdelay = df_weatherdelay.drop(['object_id','result_timestamp'], axis=1)
df = df.drop(['LC_HUMIDITY','LC_DWPTEMP','LC_n','LC_RAD','LC_RAININ',
                'LC_DAILYRAIN','LC_WINDDIR','LC_WINDSPEED','LC_RAD60','LC_TEMP_QCL0'],axis=1)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df = pd.merge(df,df_noisedelay, on='key',validate='1:1')
df= pd.merge(df,df_weatherdelay, on='key',validate='1:1')
df_nd = df.drop(['key','object_id','result_timestamp','date','time','day_time','day_hour','LC_TEMP_QCL1','LC_TEMP_QCL2','LC_TEMP_QCL3'], axis=1)

# %%
df_nd.isna().sum()
# Out:
# laeq             0
# hour             0
# weekday          0
# month            0
# weekend          0
# holiday          0
# exam_period      0
# 255439           0
# 255440           0
# 255441           0
# laeq_delayed     0
# LC_HUMIDITY     19
# LC_DWPTEMP      19
# LC_n            19
# LC_RAD          19
# LC_RAININ       19
# LC_DAILYRAIN    19
# LC_WINDDIR      19
# LC_WINDSPEED    19
# LC_RAD60         1
# LC_TEMP_QCL0    19
# dtype: int64

# %%
df_nd = df_nd[df_nd.isna()['LC_HUMIDITY']==False]
df_nd.isna().sum()
# Out:
# laeq            0
# hour            0
# weekday         0
# month           0
# weekend         0
# holiday         0
# exam_period     0
# 255439          0
# 255440          0
# 255441          0
# laeq_delayed    0
# LC_HUMIDITY     0
# LC_DWPTEMP      0
# LC_n            0
# LC_RAD          0
# LC_RAININ       0
# LC_DAILYRAIN    0
# LC_WINDDIR      0
# LC_WINDSPEED    0
# LC_RAD60        0
# LC_TEMP_QCL0    0
# dtype: int64

# %%
df_nd['weekday'] = df_nd['weekday'].replace(to_replace='Monday', value=0)
df_nd['weekday'] = df_nd['weekday'].replace(to_replace='Tuesday', value=1)
df_nd['weekday'] = df_nd['weekday'].replace(to_replace='Wednesday', value=2)
df_nd['weekday'] = df_nd['weekday'].replace(to_replace='Thursday', value=3)
df_nd['weekday'] = df_nd['weekday'].replace(to_replace='Friday', value=4)
df_nd['weekday'] = df_nd['weekday'].replace(to_replace='Saturday', value=5)
df_nd['weekday'] = df_nd['weekday'].replace(to_replace='Sunday', value=6)

# %% [markdown]
# The target dataset (y) and predictor dataset (X) are created. For y, noise is converted to relative noise (proportion of max value)

# %%
y = df_nd["laeq"]
X = df_nd.drop(["laeq"], axis="columns")

# %%
#create time-sensitive split for cross-validation
ts_cv = TimeSeriesSplit(
    n_splits=5,
    gap=12960,
    max_train_size=26300,
    test_size=18347,
)

# %%
#inspect splits
all_splits = list(ts_cv.split(X, y))
train_0, test_0 = all_splits[0]
X.iloc[test_0]
X.iloc[train_0]
# Out:
#        hour  weekday  month  weekend  holiday  exam_period  255439  255440  \
# 5         6        5      1     True     True        False   False   False
# 6         7        5      1     True     True        False   False   False
# 7         7        5      1     True     True        False   False   False
# 8         7        5      1     True     True        False   False   False
# 9         7        5      1     True     True        False   False   False
# ...     ...      ...    ...      ...      ...          ...     ...     ...
# 26300     7        0      4    False     True        False   False   False
# 26301     7        0      4    False     True        False    True   False
# 26302     7        0      4    False     True        False   False    True
# 26303     7        0      4    False     True        False   False   False
# 26304     7        0      4    False     True        False    True   False
#
#        255441  laeq_delayed  LC_HUMIDITY  LC_DWPTEMP  LC_n  LC_RAD  LC_RAININ  \
# 5        True     51.627045         90.0       11.72  38.0     0.0        0.0
# 6        True     52.079000         90.0       11.62  37.0     0.0        0.0
# 7        True     53.478833         89.0       11.58  38.0     0.0        0.0
# 8        True     51.713333         89.0       11.50  37.0     0.0        0.0
# 9        True     50.654576         89.0       11.50  38.0     0.0        0.0
# ...       ...           ...          ...         ...   ...     ...        ...
# 26300    True     45.189667         64.0        1.36  36.0     0.0        0.0
# 26301   False     39.574000         65.0        1.40  35.0     0.0        0.0
# 26302   False     39.047000         65.0        1.40  35.0     0.0        0.0
# 26303    True     45.855833         65.0        1.40  35.0     0.0        0.0
# 26304   False     39.358500         65.0        1.45  36.0     0.0        0.0
#
#        LC_DAILYRAIN  LC_WINDDIR  LC_WINDSPEED  LC_RAD60  LC_TEMP_QCL0
# 5               0.0         0.0          0.00       0.0         13.28
# 6               0.0        56.0          0.02       0.0         13.28
# 7               0.0       -24.0          0.02       0.0         13.28
# 8               0.0       -50.0          0.08       0.0         13.28
# 9               0.0       -79.0          0.05       0.0         13.28
# ...             ...         ...           ...       ...           ...
# 26300           0.0        88.0          0.62       0.0          7.76
# 26301           0.0       102.0          0.43       0.0          7.68
# 26302           0.0       102.0          0.43       0.0          7.68
# 26303           0.0       102.0          0.43       0.0          7.68
# 26304           0.0        83.0          0.36       0.0          7.55
#
# [26300 rows x 20 columns]

# %%
train_4, test_4 = all_splits[4]
X.iloc[test_4]
X.iloc[train_4]
# Out:
#        hour  weekday  month  weekend  holiday  exam_period  255439  255440  \
# 73393    17        4      7    False     True        False    True   False
# 73394    17        4      7    False     True        False   False    True
# 73395    17        4      7    False     True        False   False   False
# 73396    17        4      7    False     True        False    True   False
# 73397    17        4      7    False     True        False   False    True
# ...     ...      ...    ...      ...      ...          ...     ...     ...
# 99697    14        2      9    False    False        False    True   False
# 99698    14        2      9    False    False        False   False    True
# 99699    14        2      9    False    False        False   False   False
# 99700    14        2      9    False    False        False    True   False
# 99701    14        2      9    False    False        False   False    True
#
#        255441  laeq_delayed  LC_HUMIDITY  LC_DWPTEMP  LC_n  LC_RAD  LC_RAININ  \
# 73393   False     50.075000         45.0       12.16  32.0   547.0        0.0
# 73394   False     50.660833         45.0       12.16  32.0   547.0        0.0
# 73395    True     53.281833         45.0       12.16  32.0   547.0        0.0
# 73396   False     54.822667         44.0       12.07  32.0   564.0        0.0
# 73397   False     54.166000         44.0       12.07  32.0   564.0        0.0
# ...       ...           ...          ...         ...   ...     ...        ...
# 99697   False     55.064500         94.0        8.51  32.0    32.0        0.0
# 99698   False     56.716333         94.0        8.51  32.0    32.0        0.0
# 99699    True     57.149000         94.0        8.51  32.0    32.0        0.0
# 99700   False     55.228167         93.0        8.45  32.0    34.0        0.0
# 99701   False     55.052500         93.0        8.45  32.0    34.0        0.0
#
#        LC_DAILYRAIN  LC_WINDDIR  LC_WINDSPEED  LC_RAD60  LC_TEMP_QCL0
# 73393         0.000       118.0          0.35     526.0         24.81
# 73394         0.000       118.0          0.35     526.0         24.81
# 73395         0.000       118.0          0.35     526.0         24.81
# 73396         0.000      -162.0          0.13     533.0         25.15
# 73397         0.000      -162.0          0.13     533.0         25.15
# ...             ...         ...           ...       ...           ...
# 99697         0.003        85.0          0.01      29.0          9.34
# 99698         0.003        85.0          0.01      29.0          9.34
# 99699         0.003        85.0          0.01      29.0          9.34
# 99700         0.003        -5.0          0.00      28.0          9.61
# 99701         0.003        -5.0          0.00      28.0          9.61
#
# [26300 rows x 20 columns]

# %%
# grid search for hyperparameter tuning

param_grid = {
    'learning_rate': (0.04,0.05,0.06),
    'n_estimators': (90,100,110),
    'max_depth' : (4,5,6)}
model = xgb.XGBRegressor()
model_grid_search = GridSearchCV(model, param_grid=param_grid,
                                 n_jobs=2, cv=ts_cv)
model_grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=12960, max_train_size=26300, n_splits=5, test_size=18347),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=No...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              n_jobs=2,
#              param_grid={'learning_rate': (0.04, 0.05, 0.06),
#                          'max_depth': (4, 5, 6),
#                          'n_estimators': (90, 100, 110)})

# %%
accuracy = model_grid_search.score(X, y)
print(
    f"The test accuracy score of the grid-searched pipeline is: "
    f"{accuracy:.2f}"
)
# Out:
# The test accuracy score of the grid-searched pipeline is: 0.72

# %%
model_grid_search.predict(X.iloc[0:5])
# Out:
# array([46.857258, 46.62508 , 46.857258, 46.49005 , 46.897926],
#       dtype=float32)

# %%
print(f"The best set of parameters is: "
      f"{model_grid_search.best_params_}")
# Out:
# The best set of parameters is: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}

# %%
cv_results = pd.DataFrame(model_grid_search.cv_results_).sort_values(
    "mean_test_score", ascending=False)
cv_results.head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 13       6.751955      1.234822         0.109389        0.006697
# 12       3.457579      0.205577         0.097229        0.004713
# 14       6.754737      1.746611         0.113369        0.018009
# 21       3.706411      0.114213         0.098327        0.003926
# 5        4.634558      0.603182         0.106655        0.020345
#
#    param_learning_rate param_max_depth param_n_estimators  \
# 13                0.05               5                100
# 12                0.05               5                 90
# 14                0.05               5                110
# 21                0.06               5                 90
# 5                 0.04               5                110
#
#                                                params  split0_test_score  \
# 13  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...           0.543570
# 12  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...           0.549875
# 14  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...           0.535832
# 21  {'learning_rate': 0.06, 'max_depth': 5, 'n_est...           0.528353
# 5   {'learning_rate': 0.04, 'max_depth': 5, 'n_est...           0.552266
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 13           0.676036           0.719994           0.006902
# 12           0.683906           0.712216          -0.038524
# 14           0.671321           0.721767           0.024535
# 21           0.679430           0.718736           0.035582
# 5            0.687130           0.706477          -0.062514
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 13           0.256483         0.440597        0.270587                1
# 12           0.288952         0.439285        0.281944                2
# 14           0.233098         0.437310        0.267384                3
# 21           0.223968         0.437214        0.265711                4
# 5            0.299162         0.436504        0.288784                5

# %%
# get the parameter names
column_results = [f"param_{name}" for name in param_grid.keys()]
column_results += [
    "mean_test_score", "std_test_score", "rank_test_score"]
cv_results = cv_results[column_results]

# %%
def shorten_param(param_name):
    if "__" in param_name:
        return param_name.rsplit("__", 1)[1]
    return param_name


cv_results = cv_results.rename(shorten_param, axis=1)
cv_results
# Out:
#    param_learning_rate param_n_estimators param_max_depth  mean_test_score  \
# 13                0.05                100               5         0.440597
# 12                0.05                 90               5         0.439285
# 14                0.05                110               5         0.437310
# 21                0.06                 90               5         0.437214
# 5                 0.04                110               5         0.436504
# 16                0.05                100               6         0.434124
# 11                0.05                110               4         0.433898
# 10                0.05                100               4         0.433542
# 22                0.06                100               5         0.433228
# 17                0.05                110               6         0.432021
# 2                 0.04                110               4         0.431512
# 9                 0.05                 90               4         0.431338
# 24                0.06                 90               6         0.431035
# 18                0.06                 90               4         0.430788
# 15                0.05                 90               6         0.430282
# 19                0.06                100               4         0.429880
# 25                0.06                100               6         0.428781
# 20                0.06                110               4         0.428552
# 8                 0.04                110               6         0.428237
# 23                0.06                110               5         0.427790
# 26                0.06                110               6         0.426948
# 4                 0.04                100               5         0.425780
# 1                 0.04                100               4         0.419636
# 7                 0.04                100               6         0.415131
# 3                 0.04                 90               5         0.394121
# 0                 0.04                 90               4         0.389251
# 6                 0.04                 90               6         0.386749
#
#     std_test_score  rank_test_score
# 13        0.270587                1
# 12        0.281944                2
# 14        0.267384                3
# 21        0.265711                4
# 5         0.288784                5
# 16        0.269532                6
# 11        0.272723                7
# 10        0.280845                8
# 22        0.265511                9
# 17        0.266286               10
# 2         0.298665               11
# 9         0.292938               12
# 24        0.271565               13
# 18        0.277758               14
# 15        0.282023               15
# 19        0.269889               16
# 25        0.268588               17
# 20        0.270658               18
# 8         0.289158               19
# 23        0.268054               20
# 26        0.269028               21
# 4         0.311472               22
# 1         0.325049               23
# 7         0.309674               24
# 3         0.352584               25
# 0         0.369645               26
# 6         0.344676               27

# %%
pivoted_cv_results = cv_results.pivot_table(
    values="mean_test_score", index=["param_max_depth"],
    columns=["param_n_estimators"])

pivoted_cv_results
# Out:
# param_n_estimators       90        100       110
# param_max_depth
# 4                   0.417125  0.427686  0.431320
# 5                   0.423540  0.433202  0.433868
# 6                   0.416022  0.426012  0.429069

# %%
import seaborn as sns

ax = sns.heatmap(pivoted_cv_results, annot=True, cmap="YlGnBu", vmin=0.4,
                 vmax=0.8)
ax.invert_yaxis()

# %%
#run XGBoost model
def evaluate(model, X, y, cv):
    cv_results = cross_validate(
        model,
        X,
        y,
        cv=cv,
        scoring=["neg_mean_absolute_error", "neg_root_mean_squared_error"],
    )
    mae = -cv_results["test_neg_mean_absolute_error"]
    rmse = -cv_results["test_neg_root_mean_squared_error"]
    print(
        f"Mean Absolute Error:     {mae.mean():.3f} +/- {mae.std():.3f}\n"
        f"Root Mean Squared Error: {rmse.mean():.3f} +/- {rmse.std():.3f}"
    )

xgb_pipeline = xgb.XGBRegressor(learning_rate=0.05,n_estimators=100,max_depth=5)

evaluate(xgb_pipeline, X, y, cv=ts_cv)
# Out:
# Mean Absolute Error:     2.622 +/- 0.496
# Root Mean Squared Error: 3.780 +/- 0.797

# %%
#Qualitative analysis of the impact of features on linear model predictions
xgb_pipeline.fit(X, y)
xgb_predictions = xgb_pipeline.predict(X)

last_hours = slice(-1000, None)
fig, ax = plt.subplots(figsize=(12, 4))
fig.suptitle("Predictions by XGBoost with weather")
ax.plot(
    y.values[last_hours],
    "x-",
    alpha=0.2,
    label="Actual noise",
    color="black",
)
ax.plot(xgb_predictions[last_hours], "x-", label="xgb time features")
_ = ax.legend()

# %%
fig, axes = plt.subplots(ncols=3, figsize=(12, 4), sharey=True)
fig.suptitle(" ")
predictions = [
    xgb_predictions,
]
labels = [
    "Gradient Boosted Trees with weather and noise",
]
for ax, pred, label in zip(axes, predictions, labels):
    ax.scatter(y.values, pred, alpha=0.3, label=label)
    ax.plot([0, 80], [0, 80], "--", label="Perfect model")
    ax.set(
        xlim=(0, 80),
        ylim=(0, 80),
        xlabel="True noise",
        ylabel="Predicted noise",
    )
    ax.legend()

plt.show()

# %%
#now do the same but look at variables separately: 
# the feature importance should be lower, because dropping a variable form the model 
# will not result in a large decrease of information gain, etc if the other correlated variables take over the task of explaining the model 
#example: you can see that weekend is not as important anymore, because day takes over if weekend is in the model
features=['hour','weekday','month','weekend','holiday','exam_period','LC_HUMIDITY','LC_DWPTEMP','LC_n',
          'LC_RAD','LC_RAININ','LC_DAILYRAIN','LC_WINDDIR','LC_WINDSPEED','LC_RAD60','LC_TEMP_QCL0']
imp = importances(gbrt_pipeline, X, y, features=features) # permutation
#should be on fitted model. I used the X and y but usualy you would need to use the validation set
viz = plot_importances(imp)
viz.view()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 7
#       1 #now do the same but look at variables separately:
#       2 # the feature importance should be lower, because dropping a variable form the model
#       3 # will not result in a large decrease of information gain, etc if the other correlated variables take over the task of explaining the model
#       4 #example: you can see that weekend is not as important anymore, because day takes over if weekend is in the model
#       5 features=['hour','weekday','month','weekend','holiday','exam_period','LC_HUMIDITY','LC_DWPTEMP','LC_n',
#       6           'LC_RAD','LC_RAININ','LC_DAILYRAIN','LC_WINDDIR','LC_WINDSPEED','LC_RAD60','LC_TEMP_QCL0']
# ----> 7 imp = importances(gbrt_pipeline, X, y, features=features) # permutation
#       8 #should be on fitted model. I used the X and y but usualy you would need to use the validation set
#       9 viz = plot_importances(imp)
#
# NameError: name 'importances' is not defined

# %%
df
# Out:
#         object_id    result_timestamp       laeq        date      time  hour
# 0          255441 2022-01-01 06:00:00  46.043333  2022-01-01  06:00:00     6  \
# 1          255441 2022-01-01 06:10:00  45.743000  2022-01-01  06:10:00     6
# 2          255441 2022-01-01 06:20:00  48.452167  2022-01-01  06:20:00     6
# 3          255441 2022-01-01 06:30:00  45.736167  2022-01-01  06:30:00     6
# 4          255441 2022-01-01 06:40:00  44.955333  2022-01-01  06:40:00     6
# ...           ...                 ...        ...         ...       ...   ...
# 131013     255441 2022-12-31 23:10:00  53.712833  2022-12-31  23:10:00    23
# 131014     255441 2022-12-31 23:20:00  55.333167  2022-12-31  23:20:00    23
# 131015     255441 2022-12-31 23:30:00  56.797333  2022-12-31  23:30:00    23
# 131016     255441 2022-12-31 23:40:00  61.010667  2022-12-31  23:40:00    23
# 131017     255441 2022-12-31 23:50:00  58.354424  2022-12-31  23:50:00    23
#
#          weekday  month  weekend           day_time  ... LC_HUMIDITY
# 0       Saturday      1     True  Saturday 06:00:00  ...         NaN  \
# 1       Saturday      1     True  Saturday 06:10:00  ...        91.0
# 2       Saturday      1     True  Saturday 06:20:00  ...        90.0
# 3       Saturday      1     True  Saturday 06:30:00  ...        90.0
# 4       Saturday      1     True  Saturday 06:40:00  ...        90.0
# ...          ...    ...      ...                ...  ...         ...
# 131013  Saturday     12     True  Saturday 23:10:00  ...        65.0
# 131014  Saturday     12     True  Saturday 23:20:00  ...        66.0
# 131015  Saturday     12     True  Saturday 23:30:00  ...        66.0
# 131016  Saturday     12     True  Saturday 23:40:00  ...        65.0
# 131017  Saturday     12     True  Saturday 23:50:00  ...        64.0
#
#         LC_DWPTEMP  LC_n  LC_RAD  LC_RAININ  LC_DAILYRAIN  LC_WINDDIR
# 0              NaN   NaN     NaN        NaN           NaN         NaN  \
# 1            11.88  38.0     0.0        0.0         0.000       -48.0
# 2            11.72  37.0     0.0        0.0         0.000        45.0
# 3            11.72  38.0     0.0        0.0         0.000       -52.0
# 4            11.72  37.0     0.0        0.0         0.000        34.0
# ...            ...   ...     ...        ...           ...         ...
# 131013        9.48  38.0     0.0        0.0         0.001       -28.0
# 131014        9.50  37.0     0.0        0.0         0.001        38.0
# 131015        9.43  38.0     0.0        0.0         0.001        46.0
# 131016        9.19  37.0     0.0        0.0         0.001        10.0
# 131017        8.95  38.0     0.0        0.0         0.001        30.0
#
#         LC_WINDSPEED  LC_RAD60 LC_TEMP_QCL0
# 0                NaN       NaN          NaN
# 1               0.04       0.0        13.28
# 2               0.02       0.0        13.28
# 3               0.04       0.0        13.28
# 4               0.02       0.0        13.28
# ...              ...       ...          ...
# 131013          0.17       0.0        15.95
# 131014          0.31       0.0        15.89
# 131015          0.26       0.0        15.79
# 131016          0.39       0.0        15.78
# 131017          0.43       0.0        15.78
#
# [131018 rows x 31 columns]

# %%
#predict nighttime values only
df_night = df.set_index('result_timestamp')

# %%
df_night = df_night.between_time(start_time='22:00:00', end_time='6:00:00', inclusive='left')
df_night = df_night.reset_index()
df_nd_n = df_night.drop(['key','object_id','result_timestamp','date','time','day_time','day_hour','LC_TEMP_QCL1','LC_TEMP_QCL2','LC_TEMP_QCL3'], axis=1)

# %%
df_nd_n = df_nd_n[df_nd_n.isna()['LC_HUMIDITY']==False]
df_nd_n.isna().sum()
# Out:
# laeq            0
# hour            0
# weekday         0
# month           0
# weekend         0
# holiday         0
# exam_period     0
# 255439          0
# 255440          0
# 255441          0
# laeq_delayed    0
# LC_HUMIDITY     0
# LC_DWPTEMP      0
# LC_n            0
# LC_RAD          0
# LC_RAININ       0
# LC_DAILYRAIN    0
# LC_WINDDIR      0
# LC_WINDSPEED    0
# LC_RAD60        0
# LC_TEMP_QCL0    0
# dtype: int64

# %%
df_nd_n['weekday'] = df_nd_n['weekday'].replace(to_replace='Monday', value=0)
df_nd_n['weekday'] = df_nd_n['weekday'].replace(to_replace='Tuesday', value=1)
df_nd_n['weekday'] = df_nd_n['weekday'].replace(to_replace='Wednesday', value=2)
df_nd_n['weekday'] = df_nd_n['weekday'].replace(to_replace='Thursday', value=3)
df_nd_n['weekday'] = df_nd_n['weekday'].replace(to_replace='Friday', value=4)
df_nd_n['weekday'] = df_nd_n['weekday'].replace(to_replace='Saturday', value=5)
df_nd_n['weekday'] = df_nd_n['weekday'].replace(to_replace='Sunday', value=6)

# %%
y_night = df_nd_n["laeq"]
X_night = df_nd_n.drop("laeq", axis="columns")

# %%
predictions = xgb_pipeline.predict(X_night)
predictions
# Out:
# array([51.938446, 52.11555 , 52.11555 , ..., 51.395412, 51.440113,
#        51.440113], dtype=float32)

# %%
MAE = sum(((predictions-y_night)**2)**(1/2))/len(y_night)
MAE
# Out:
# 2.2288501587426275

# %%
RMSE = (sum((predictions-y_night)**2)/len(y_night))**(1/2)
RMSE
# Out:
# 3.1293852565058216

# %% [markdown]
# Shapley values

# %%
xgb_pipeline = xgb.XGBRegressor(learning_rate=0.05,n_estimators=100,max_depth=5)

# %%
import shap

def plot_shaply(pipeline_step):
    #this model calculates shapley values for all models previously introduced
    SHAP_values_per_fold = [] #-#-#

    for i in range(len(all_splits)):
        X_train=X.iloc[all_splits[i][0]]
        X_test=X.iloc[all_splits[i][1]]
        y_train=y.iloc[all_splits[i][0]]
        y_test=y.iloc[all_splits[i][1]]


        

        model = pipeline_step
        fit = model.fit(X_train, y_train)
        
        # Use SHAP to explain predictions
        explainer = shap.Explainer(model)
        shap_values = explainer.shap_values(X_test)
        for SHAPs in shap_values:
            SHAP_values_per_fold.append(SHAPs) #-#-#

    #print(SHAP_values_per_fold)
    ix_training, ix_test = [], []
    # Loop through each fold and append the training & test indices to the empty lists above
    for fold in ts_cv.split(df):
        ix_training.append(fold[0]), ix_test.append(fold[1])
    #create new index for Shapley values
    new_index = [ix for ix_test_fold in ix_test for ix in ix_test_fold]
    #plot shapley values
    shap.summary_plot(np.array(SHAP_values_per_fold), X.reindex(new_index))

#Shapley values for gbrt_pipeline
plot_shaply(xgb_pipeline)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# explain the model's predictions using SHAP this is a great way of showing how different variables determine the prediction: even nice as a visualisation
explainer = shap.Explainer(xgb_pipeline)
shap_values = explainer.shap_values(df)

# visualize the first prediction's explanation 
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[0,:], X_train.iloc[0,:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7780\4094606469.py in <module>
#       1 # explain the model's predictions using SHAP this is a great way of showing how different variables determine the prediction: even nice as a visualisation
#       2 explainer = shap.Explainer(xgb_pipeline)
# ----> 3 shap_values = explainer.shap_values(df)
#       4
#       5 # visualize the first prediction's explanation
#
# c:\Users\saaan\anaconda3\lib\site-packages\shap\explainers\_tree.py in shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     326                 import xgboost
#     327                 if not isinstance(X, xgboost.core.DMatrix):
# --> 328                     X = xgboost.DMatrix(X)
#     329                 if tree_limit == -1:
#     330                     tree_limit = 0
#
# c:\Users\saaan\anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# c:\Users\saaan\anaconda3\lib\site-packages\xgboost\core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     741             return
#     742
# --> 743         handle, feature_names, feature_types = dispatch_data_backend(
#     744             data,
#     745             missing=self.missing,
#
# c:\Users\saaan\anaconda3\lib\site-packages\xgboost\data.py in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     968         return _from_tuple(data, missing, threads, feature_names, feature_types)
#     969     if _is_pandas_df(data):
# --> 970         return _from_pandas_df(data, enable_categorical, missing, threads,
#     971                                feature_names, feature_types)
#     972     if _is_pandas_series(data):
#
# c:\Users\saaan\anaconda3\lib\site-packages\xgboost\data.py in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     415     feature_types: Optional[FeatureTypes],
#     416 ) -> DispatchedDataBackendReturnType:
# --> 417     data, feature_names, feature_types = _transform_pandas_df(
#     418         data, enable_categorical, feature_names, feature_types
#     419     )
#
# c:\Users\saaan\anaconda3\lib\site-packages\xgboost\data.py in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     389         for dtype in data.dtypes
#     390     ):
# --> 391         _invalid_dataframe_dtype(data)
#     392
#     393     feature_names, feature_types = _pandas_feature_info(
#
# c:\Users\saaan\anaconda3\lib\site-packages\xgboost\data.py in _invalid_dataframe_dtype(data)
#     281     type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     282     msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 283     raise ValueError(msg)
#     284
#     285
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:result_timestamp: datetime64[ns], date: object, time: object, weekday: object, day_time: object, day_hour: object, key: object
